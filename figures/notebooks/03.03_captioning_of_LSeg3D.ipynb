# %%
import os
import sys

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"

module_path = os.path.abspath(os.path.join("../.."))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import json

import matplotlib.pyplot as plt
import numpy as np
import open3d as o3d
import torch
import pandas as pd
from PIL import Image

from core.captioner import ClipCapCaptioner, DeCapCaptioner
from core.dataset import ScanNet
from core.integrate import FeatureFusionScalableTSDFVolume
from core.labeler import CLIPTextQuerier, KMeansLabeler

# %% [markdown]
# # STEP 1: get ground truth semantic seg and vertices

# %%
dataset = ScanNet('/home/quanta/Datasets/ScanNet/')
nyu40_color = dataset.nyu40id_to_color
nyu40_class = [dataset.nyu40_id_to_class[i] for i in range(41)]

# %%
scene = "scannet_scene0000_00"
load_dir = "/home/quanta/Experiments/feature-instance-fusion/" + scene + "/"

# %%
json_pth = os.path.abspath("../../config/views/" + scene + ".json")
with open(json_pth, "r") as f:
    views = json.load(f)['views']

# %%
verts = np.load(load_dir + "tsdf/verts.npy")
faces = np.load(load_dir + "tsdf/faces.npy")

# %%
tsdf_device = "cuda:1"
tsdf_volume = FeatureFusionScalableTSDFVolume(
    voxel_size=0.015,
    sdf_trunc=0.075,
    margin=0.08,
    device="cuda:1",
)
tsdf_volume.load(load_dir + "tsdf/tsdf_volume_unpruned.pt")
tsdf_volume.load_feats(load_dir + 'tsdf_feature_gt_semantic/feats.pt')

# %%
gt_labels = np.argmax(tsdf_volume.extract_feat_on_grid(verts=verts)[0], axis=1)

# %%
gt_counts = np.bincount(gt_labels, minlength=41)

# %% [markdown]
# # STEP 2: get LSeg feats

# %%
tsdf_volume.load_feats(load_dir + "tsdf_feature_lseg/feats.pt")

# %%
lseg_feats = tsdf_volume.extract_feat_on_grid(verts=verts, device='cpu')[0]

# %%
del tsdf_volume
torch.cuda.empty_cache()

# %%
decap = DeCapCaptioner(
    decap_ckpt="/home/quanta/Models/decap/coco_prefix-009.pt",
    device=tsdf_device,
)
decap.load_model()

# %% [markdown]
# ## Random choice

# %%
repeat = 10
random_feat_decode = []
for i in range(41):
    choices = np.argwhere(gt_labels == i).reshape(-1)

    if len(choices) == 0:
        random_feat_decode.append([""] * repeat)
        continue

    decoded_sents = []

    for i in range(repeat):
        idx = np.random.choice(choices)
        feat = torch.from_numpy(lseg_feats[idx, :])
        text = decap.get_caption(feat)
        decoded_sents.append(text)

    random_feat_decode.append(decoded_sents)

# %%
random_decode = pd.DataFrame(np.array(random_feat_decode))

# %%
random_decode
# Out:
#                                                     0  \
# 0                              a wall with the other
# 1    wall with the side of a wall , one of the other
# 2                     rug that is very large and rug
# 3                             a shelf of the cabinet
# 4                                            a couch
# 5
# 6                                            a couch
# 7                         a table that has been used
# 8                   some kind of door that is door .
# 9                                     window of open
# 10
# 11
# 12                              a wall with the word
# 13
# 14                              a table with the top
# 15                          the cabinet of a cabinet
# 16                                         a curtain
# 17
# 18                                             a bed
# 19                                   a light of wall
# 20
# 21
# 22              ceiling that is hanging from ceiling
# 23
# 24  the cabinet of the electronic equipment in par...
# 25                                a tv with the back
# 26
# 27
# 28
# 29
# 30
# 31
# 32                                    the table of a
# 33                                          a toilet
# 34                                          a toilet
# 35
# 36
# 37
# 38                               some kind of door .
# 39                                     a wall of the
# 40                                           a chair
#
#                                                    1  \
# 0                                           a table
# 1   wall with the side of a wall , one of the other
# 2                    a floor of a room of the floor
# 3                                      a television
# 4                                             a bed
# 5
# 6                                           a couch
# 7                                           a table
# 8                  some kind of door that is door .
# 9                                    window of open
# 10
# 11
# 12                                           a sink
# 13
# 14                               a floor of a table
# 15                       a shelf that has been used
# 16                                        a curtain
# 17
# 18                                 a person with it
# 19                          a few mirror that is by
# 20
# 21
# 22           ceiling that is hanging in the ceiling
# 23
# 24                                   a refrigerator
# 25                                             a tv
# 26
# 27
# 28
# 29
# 30
# 31
# 32                               table with the top
# 33                                         a toilet
# 34                                           a sink
# 35
# 36
# 37
# 38                              some kind of door .
# 39                                         a toilet
# 40                               a wall of a person
#
#                                      2  \
# 0                the wall of a single
# 1                         some door .
# 2   a rug that is very long and floor
# 3                           a curtain
# 4                             a couch
# 5
# 6                             a couch
# 7             a counter with the wall
# 8                a few mirror in it .
# 9                      window of open
# 10
# 11
# 12               the corner of a wall
# 13
# 14                            a table
# 15                             a book
# 16                          a curtain
# 17
# 18               a wall with the back
# 19  a door that has some kind of door
# 20
# 21
# 22    the ceiling of a lot of ceiling
# 23
# 24                     a refrigerator
# 25                               a tv
# 26
# 27
# 28
# 29
# 30
# 31
# 32               the wall of a single
# 33                           a toilet
# 34                             a door
# 35
# 36
# 37
# 38  a door that has some kind of door
# 39                            a table
# 40                          a bicycle
#
#                                                    3  \
# 0                                           a chair
# 1   the wall of a cluttered and - fashioned cabinet
# 2               a floor of a floor of a flat - over
# 3                                         a curtain
# 4                                             a bed
# 5
# 6                                           a couch
# 7                                           a table
# 8                  some kind of door that is door .
# 9                                    window of open
# 10
# 11
# 12                                        a counter
# 13
# 14                                  a table with it
# 15                 the cabinet of a cluttered floor
# 16                                        a bicycle
# 17
# 18                             a bed with some back
# 19               a mirror with some kind of stuff .
# 20
# 21
# 22                  the ceiling of a lot of ceiling
# 23
# 24                                   a refrigerator
# 25                                             a tv
# 26
# 27
# 28
# 29
# 30
# 31
# 32                       a table that has been used
# 33                                         a toilet
# 34                                  a wall of it 's
# 35
# 36
# 37
# 38                                       a light of
# 39                                a floor of a room
# 40                                          a chair
#
#                                           4  \
# 0                                  a couch
# 1                      some kind of door .
# 2      a floor of a floor of a flat - over
# 3                   a shelf of the cabinet
# 4                                    a bed
# 5
# 6                                a bicycle
# 7                                  a table
# 8         some kind of door that is door .
# 9                           window of open
# 10
# 11
# 12                               a counter
# 13
# 14                                 a table
# 15                                 a couch
# 16                               a bicycle
# 17
# 18                                  a wall
# 19                         a light of wall
# 20
# 21
# 22  ceiling that is hanging in the ceiling
# 23
# 24                          a refrigerator
# 25                                    a tv
# 26
# 27
# 28
# 29
# 30
# 31
# 32                           a rug that is
# 33                     a wall with the lid
# 34                            a wall of it
# 35
# 36
# 37
# 38                     some kind of door .
# 39                                a toilet
# 40                         a back of a rug
#
#                                                    5  \
# 0                                    window of open
# 1   wall with the side of a wall , one of the other
# 2                                         a bicycle
# 3                                              a tv
# 4                                             a bed
# 5
# 6                                           a couch
# 7                         a wall with the door open
# 8             some door that has been made and door
# 9                                    window of open
# 10
# 11
# 12                                        a counter
# 13
# 14                              a floor of the room
# 15            the wall of a single , and other wall
# 16                                        a curtain
# 17
# 18                                            a bed
# 19                         a few things in a mirror
# 20
# 21
# 22             ceiling that is hanging from ceiling
# 23
# 24                  a floor of an open refrigerator
# 25                                             a tv
# 26
# 27
# 28
# 29
# 30
# 31
# 32                                        the table
# 33                        a wall with the lid of it
# 34                                         a toilet
# 35
# 36
# 37
# 38                            some kind of mirror .
# 39                                         a toilet
# 40                                        a bicycle
#
#                                                     6  \
# 0                                       table with a
# 1                                        some door .
# 2                        a floor of a floor of a new
# 3   the cabinet of the electronic equipment in par...
# 4                                              a bed
# 5
# 6                 the cabinet of a cluttered cabinet
# 7                                             a back
# 8                   some kind of door that is door .
# 9                                     window of open
# 10
# 11
# 12                                         a counter
# 13
# 14                                           a chair
# 15                   a book in the back of the night
# 16                                         a curtain
# 17
# 18                      a wall with the bottom of it
# 19                                a few mirror of it
# 20
# 21
# 22          ceiling that is being flown in a ceiling
# 23
# 24                                    a refrigerator
# 25                                a tv with the back
# 26
# 27
# 28
# 29
# 30
# 31
# 32                              the wall of a single
# 33                                          a toilet
# 34                                          a toilet
# 35
# 36
# 37
# 38                               some kind of door .
# 39                              a floor of the floor
# 40                                         a bicycle
#
#                                        7  \
# 0            a table that has been used
# 1              window of an open window
# 2   a floor of a floor of a flat - over
# 3                 a cabinet of the door
# 4                                 a bed
# 5
# 6                               a couch
# 7                  a table with the top
# 8      some kind of door that is door .
# 9                        window of open
# 10
# 11
# 12                            a counter
# 13
# 14                      a table with it
# 15        a book with a number of books
# 16                            a curtain
# 17
# 18                                a bed
# 19           a window with all the side
# 20
# 21
# 22             the ceiling of a ceiling
# 23
# 24   the wall of a wall with a single ,
# 25                                 a tv
# 26
# 27
# 28
# 29
# 30
# 31
# 32                   the end of a table
# 33                             a toilet
# 34                               a sink
# 35
# 36
# 37
# 38    a wall that has been cut and door
# 39                        table with it
# 40                          a microwave
#
#                                                    8  \
# 0                                    a refrigerator
# 1   wall with the side of a wall , one of the other
# 2                      a floor of a floor of a flat
# 3                                         a bicycle
# 4                       a rug that is very long and
# 5
# 6                                           a couch
# 7                                           a table
# 8                  some kind of door that is door .
# 9             window of an open wall with the other
# 10
# 11
# 12                        the wall of a single wall
# 13
# 14                                        a curtain
# 15                              a book with the top
# 16                                        a curtain
# 17
# 18                                 a person with it
# 19                         a few things in a mirror
# 20
# 21
# 22             ceiling that is hanging from ceiling
# 23
# 24                                   a refrigerator
# 25                                             a tv
# 26
# 27
# 28
# 29
# 30
# 31
# 32                                    table with it
# 33                                         a toilet
# 34                                         a toilet
# 35
# 36
# 37
# 38                            some kind of mirror .
# 39                    a floor of a floor of an open
# 40                                        a bicycle
#
#                                           9
# 0                            a wall of the
# 1                           a wall with it
# 2      a floor of a floor of a flat - over
# 3                     a wall with the word
# 4                   a bed with some sheets
# 5
# 6                                  a couch
# 7                                  a table
# 8         some kind of door that is door .
# 9                window of open and window
# 10
# 11
# 12                               a counter
# 13
# 14                                 a table
# 15                     a book with the top
# 16                               a curtain
# 17
# 18                                   a bed
# 19           a door with some kind of door
# 20
# 21
# 22  ceiling that is hanging in the ceiling
# 23
# 24                          a refrigerator
# 25                                    a tv
# 26
# 27
# 28
# 29
# 30
# 31
# 32                           table with it
# 33               a wall with the lid of it
# 34                                  a sink
# 35
# 36
# 37
# 38       a door that has some kind of wall
# 39                    a floor of the floor
# 40                          a wall of wood

# %% [markdown]
# ## Mean decode

# %%
mean_decode = []
for i in range(41):
    choices = np.argwhere(gt_labels == i).reshape(-1)

    if choices.shape[0] == 0:
        mean_decode.append("")
        continue

    feat = torch.from_numpy(lseg_feats[choices, :]).mean(dim=0)
    text = decap.get_caption(feat)
    mean_decode.append(text)

# %%
mean_decode = pd.DataFrame(mean_decode)

# %%
mean_decode
# Out:
#                                           0
# 0                              a back of a
# 1   the wall of a wall with a lot of other
# 2         a floor of a room with the floor
# 3                   a cabinet with the top
# 4                                    a bed
# 5
# 6                                  a couch
# 7                                   a wall
# 8                      some kind of door .
# 9                           window of open
# 10
# 11
# 12                               a counter
# 13
# 14                                 a table
# 15                  a cabinet with the top
# 16                               a curtain
# 17
# 18                                   a bed
# 19               a few mirror of some sort
# 20
# 21
# 22         the ceiling of a lot of ceiling
# 23
# 24                          a refrigerator
# 25                                    a tv
# 26
# 27
# 28
# 29
# 30
# 31
# 32                 a table with the bottom
# 33                                a toilet
# 34                                a toilet
# 35
# 36
# 37
# 38                     some kind of door .
# 39                                a toilet
# 40                             a back of a

# %%
feat_count = pd.DataFrame(gt_counts)

# %%
class_name = pd.DataFrame(nyu40_class)

# %%
save_dir = '../03_caption/03_LSeg_3D_caption/'
os.makedirs(save_dir, exist_ok=True)

# %%
random_decode.to_csv(save_dir + 'random_decode.csv', index=False, header=False)
mean_decode.to_csv(save_dir + 'mean_decode.csv', index=False, header=False)
feat_count.to_csv(save_dir + 'semantic_count.csv', index=False, header=False)
class_name.to_csv(save_dir + 'semantic_name.csv', index=False, header=False)
